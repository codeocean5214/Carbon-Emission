# %%
#Creating a Syntecthic dataset in order to mimic the real Conditions  
#

# %%
import time 
import uuid
import random 
import math 
from datetime import datetime,timezone 
import threading 
import json
import os
import csv
from pathlib import Path

# %%
"""these are all the default parameters that were set up by observing three data sets 
for demonstration of realism 
   1. GEOLIFE - MICROSOFT 
   2. Electricity consumption dataset  -- https://archive.ics.uci.edu/ml/datasets/individual+household+electric+power+consumption
   3. Industrial Emission - Government of India - Scrapped by beautiful soup
"""
transport_inteval = 1 
electricity_interval = 60 
industry_interval = 10 

num_user  = int(os.getenv("num_user",5))
num_houses = int(os.getenv("num_houses",3))
num_factories = int(os.getenv("num_factories",2))

"""Getting current date and time"""
def current_datetime(): 
    return datetime.now(timezone.utc).isoformat()

"""Json return type -- how the date will be saved
Entity defines what generates the carbon emission , then value and unit 
are stheir to store the corresponding value"""
def event(sector,entity_id,value,unit,details=None): 
    return  { 
        "id" : str(uuid.uuid4()), 
        "sector" : sector,
        "entity_id" : entity_id,
        "activity_value" : round(value,3), 
        "activity_unit" : unit, 
        "timestamp" : current_datetime(), 
        "metadata": {
            "source": "synthetic",
            "details": details or {}
        }

    }
def print_event(event) : 
    print(json.dumps(event))

"""Saving the data in the csv"""
Path("data/stream").mkdir(parents=True,exist_ok=True)
files =  {
    "transport": open("data/stream/transport_events.csv", "a", newline=""),
    "electricity": open("data/stream/electricity_events.csv", "a", newline=""),
    "industry": open("data/stream/industry_events.csv", "a", newline="")
}


write = { 
    sector:csv.writer(f) for sector,f in files.items()
}
def save_csv(event) : 
    w=write[event["sector"]]
    w.writerow([
        event["id"],
        event["sector"],
        event["entity_id"],
        event["activity_value"],
        event["activity_unit"],
        event["timestamp"],
        json.dumps(event["metadata"])
    ])
    files[event["sector"]].flush()

# %%
def transport_generator():
    """
    Simulates per-second movement using speed distributions
    """
    users = [f"user_{i}" for i in range(1, num_user + 1)]

    while True:
        for user in users:
            speed_kmh = max(5, random.lognormvariate(3.0, 0.4))
            distance_km = speed_kmh / 3600  

            newevent = event(
                sector="transport",
                entity_id=user,
                value=distance_km,
                unit="km",
                details={
                    "speed_kmh": round(speed_kmh, 2)
                }
            )
            print_event(newevent)
            save_csv(newevent)

        time.sleep(transport_inteval)

def electricity_generator(): 
    houses = [f"house_{i}" for i in range(1, num_houses + 1)]
    while True:
        hour = datetime.now().hour
        for house in houses:
            base_load = random.uniform(0.001, 0.003)
            peak_multiplier = 2 if 18 <= hour <= 22 else 1
            kwh = base_load * peak_multiplier
            newevent =event(
                sector="electricity",
                entity_id=house,
                value=kwh,
                unit="kWh",
                details={
                    "hour": hour,
                    "peak": peak_multiplier > 1
                }
            )
            print_event(newevent)
            save_csv(newevent)

        time.sleep(electricity_interval)
def industry_generator(): 
    factories  = [f"factory_{i}" for i in range(1,num_factories+1)]
    while True : 
        for factory in factories : 
            hour  = datetime.now().hour 
        if 8 <= hour <= 20:
            energy_kwh = random.uniform(5, 15)
            active = True
        else:
            energy_kwh = random.uniform(1, 3)
            active = False
        newevent = event(
                sector="industry",
                entity_id=factory,
                value=energy_kwh,
                unit="kWh",
                details={
                    "active_shift": active
                }
            )
        print_event(newevent)
        save_csv(newevent)
        time.sleep(industry_interval)

# %%
if __name__  == "__main__" : 
    threads  = [ 
        threading.Thread(target=transport_generator,daemon=True),
        threading.Thread(target=electricity_generator,daemon=True),
        threading.Thread(target=industry_generator,daemon=True)
    ]
    for t in threads : 
        t.start()
    while True : 
        time.sleep(1)
# Out:
# {"id": "93e0f6e0-d44f-470c-afbd-c1291d95de91", "sector": "transport", "entity_id": "user_1", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:34:40.189783+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 23.16}}}
# {"id": "44467791-f19e-4508-98d2-59e9361237c4", "sector": "transport", "entity_id": "user_2", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:34:40.190397+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 18.05}}}
# {"id": "5c8df16b-867e-43e3-a63a-09be0f31cc2b", "sector": "transport", "entity_id": "user_3", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:34:40.190504+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 20.06}}}
# {"id": "ec408c11-e4a6-4ad1-a099-73b649367006", "sector": "transport", "entity_id": "user_4", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:34:40.190611+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 10.93}}}
# {"id": "e35d8810-c586-4689-a337-26e4647184c3", "sector": "transport", "entity_id": "user_5", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:34:40.190698+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 23.77}}}
# {"id": "1fae73bf-96c5-4c67-9a83-c25819ef46b9", "sector": "electricity", "entity_id": "house_1", "activity_value": 0.001, "activity_unit": "kWh", "timestamp": "2026-01-12T09:34:40.190949+00:00", "metadata": {"source": "synthetic", "details": {"hour": 9, "peak": false}}}
# {"id": "c67c01d1-29fb-45db-8dc2-bfc702d01ce3", "sector": "industry", "entity_id": "factory_2", "activity_value": 7.468, "activity_unit": "kWh", "timestamp": "2026-01-12T09:34:40.191318+00:00", "metadata": {"source": "synthetic", "details": {"active_shift": true}}}
# {"id": "74811517-7d48-488b-a7a7-45387ddd13d2", "sector": "electricity", "entity_id": "house_2", "activity_value": 0.002, "activity_unit": "kWh", "timestamp": "2026-01-12T09:34:40.191481+00:00", "metadata": {"source": "synthetic", "details": {"hour": 9, "peak": false}}}
# {"id": "4888ccc6-9583-42b3-a42e-e129c730bc3a", "sector": "electricity", "entity_id": "house_3", "activity_value": 0.002, "activity_unit": "kWh", "timestamp": "2026-01-12T09:34:40.191600+00:00", "metadata": {"source": "synthetic", "details": {"hour": 9, "peak": false}}}
# {"id": "1f3dc041-8541-4eed-a2a2-772cbf9927f8", "sector": "transport", "entity_id": "user_1", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:34:41.190953+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 16.63}}}
# {"id": "389ed1f7-6009-40b6-be61-e17117f3d9e9", "sector": "transport", "entity_id": "user_2", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:34:41.191442+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 27.43}}}
# {"id": "46c388c1-8e1b-408b-b048-691cc4dfa596", "sector": "transport", "entity_id": "user_3", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:34:41.191599+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 17.83}}}
# {"id": "78629d2f-c4d1-4d43-b335-2b07ed6a42f4", "sector": "transport", "entity_id": "user_4", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:34:41.191837+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 11.77}}}
# {"id": "d433e5a0-be26-41af-9c7a-dd1553a6a26b", "sector": "transport", "entity_id": "user_5", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:34:41.192003+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 19.57}}}
# {"id": "38516776-7bfa-46af-8610-d39e08e0a20e", "sector": "transport", "entity_id": "user_1", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:34:42.192256+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 17.45}}}
# {"id": "f4f0bc6d-c549-41e4-9f30-1a4fb471d4a0", "sector": "transport", "entity_id": "user_2", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:34:42.192749+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 17.35}}}
# {"id": "c4a99263-ef18-42b8-9850-df2a3697eaa5", "sector": "transport", "entity_id": "user_3", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:34:42.192925+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 17.71}}}
# {"id": "ebea31ad-81da-4d9c-9e6c-0eab9da355aa", "sector": "transport", "entity_id": "user_4", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:34:42.193051+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 13.96}}}
# {"id": "a7df48c4-0629-4bf9-a31d-bb1033a88b46", "sector": "transport", "entity_id": "user_5", "activity_value": 0.009, "activity_unit": "km", "timestamp": "2026-01-12T09:34:42.193173+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 31.69}}}
# {"id": "1ff451da-aa85-410d-9d2c-d87d16c2d0bd", "sector": "transport", "entity_id": "user_1", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:34:43.193416+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 13.05}}}
# {"id": "470b9db5-fe9f-4994-9519-e137880d9514", "sector": "transport", "entity_id": "user_2", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:34:43.193853+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 12.95}}}
# {"id": "9adc36f5-ee8f-44cf-8c99-365510c1c188", "sector": "transport", "entity_id": "user_3", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:34:43.193972+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 17.26}}}
# {"id": "d76a4299-6ed1-43cb-8db5-c450688e7ac0", "sector": "transport", "entity_id": "user_4", "activity_value": 0.009, "activity_unit": "km", "timestamp": "2026-01-12T09:34:43.194083+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 31.91}}}
# {"id": "5b0e3e11-8225-4247-b382-087d15652882", "sector": "transport", "entity_id": "user_5", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:34:43.194175+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 17.26}}}
# {"id": "42eabe34-dda2-48fc-bd18-5fa761c4a9d5", "sector": "transport", "entity_id": "user_1", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:34:44.194399+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 29.74}}}
# {"id": "2a2c786a-a396-4c1f-a0b2-ceab76fb4712", "sector": "transport", "entity_id": "user_2", "activity_value": 0.01, "activity_unit": "km", "timestamp": "2026-01-12T09:34:44.194896+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 36.36}}}
# {"id": "a47e9143-25bc-4122-8942-3262f17f5324", "sector": "transport", "entity_id": "user_3", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:34:44.195006+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 9.11}}}
# {"id": "266b2427-78c2-40ab-baf4-79d82e94347e", "sector": "transport", "entity_id": "user_4", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:34:44.195107+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 29.15}}}
# {"id": "87a2ebe4-39e3-49cd-87cc-57495fe0025b", "sector": "transport", "entity_id": "user_5", "activity_value": 0.011, "activity_unit": "km", "timestamp": "2026-01-12T09:34:44.195191+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 38.61}}}
# {"id": "8ef2db2b-9876-4698-92e6-b0fececbcfe0", "sector": "transport", "entity_id": "user_1", "activity_value": 0.01, "activity_unit": "km", "timestamp": "2026-01-12T09:34:45.195421+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 34.89}}}
# {"id": "bb39765c-0fa9-48ef-a0c5-8ab78abfcfcf", "sector": "transport", "entity_id": "user_2", "activity_value": 0.002, "activity_unit": "km", "timestamp": "2026-01-12T09:34:45.196047+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 6.57}}}
# {"id": "bf5f822f-0376-411a-979c-5bd8cdcd4749", "sector": "transport", "entity_id": "user_3", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:34:45.196202+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 16.13}}}
# {"id": "508c8ed1-6e66-43a0-9c0c-06ce8a338d8b", "sector": "transport", "entity_id": "user_4", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:34:45.196333+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 9.44}}}
# {"id": "68ab7598-d6d9-457c-9760-b46b08a02acc", "sector": "transport", "entity_id": "user_5", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:34:45.196476+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 22.23}}}
# {"id": "5ca8bd20-90eb-463f-92ac-9899d9693928", "sector": "transport", "entity_id": "user_1", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:34:46.196718+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 25.76}}}
# {"id": "ffd271bb-6115-48a2-8e86-06d53549fce1", "sector": "transport", "entity_id": "user_2", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:34:46.197208+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 16.41}}}
# {"id": "40b07f6b-7f3a-4d26-ad05-3df6e6c88606", "sector": "transport", "entity_id": "user_3", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:34:46.197343+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 19.84}}}
# {"id": "2f824fe4-df49-40f7-8e53-e2ad783847c3", "sector": "transport", "entity_id": "user_4", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:34:46.197466+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 12.51}}}
# {"id": "4868ea84-396d-46b8-aec3-2591c25b6661", "sector": "transport", "entity_id": "user_5", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:34:46.197564+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 23.35}}}
# {"id": "ae888241-ce23-40c7-8cfa-57d3298a269f", "sector": "transport", "entity_id": "user_1", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:34:47.197846+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 23.85}}}
# {"id": "da3ee872-1313-4a35-a7df-a1c23b99f69e", "sector": "transport", "entity_id": "user_2", "activity_value": 0.009, "activity_unit": "km", "timestamp": "2026-01-12T09:34:47.198332+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 31.12}}}
# {"id": "e8be1fd0-3f13-440d-88c3-2fa7f1ff7981", "sector": "transport", "entity_id": "user_3", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:34:47.198477+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 19.81}}}
# {"id": "7b4f54f1-980c-4577-b4dd-e0060b88b202", "sector": "transport", "entity_id": "user_4", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:34:47.198586+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 13.52}}}
# {"id": "7c700631-fe27-4844-89cc-5a4fe95020b3", "sector": "transport", "entity_id": "user_5", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:34:47.198676+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 17.99}}}
# {"id": "a954c31b-b5f9-497e-9cc5-37ac8db78604", "sector": "transport", "entity_id": "user_1", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:34:48.198899+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 13.6}}}
# {"id": "56b477d6-69c6-4c98-9bb8-9677e5ec7f25", "sector": "transport", "entity_id": "user_2", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:34:48.199376+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 26.43}}}
# {"id": "fdd37271-41a2-4000-beeb-6abba1a304ce", "sector": "transport", "entity_id": "user_3", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:34:48.199498+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 13.23}}}
# {"id": "11cae44a-b80a-4fef-8cef-77b96bbb8405", "sector": "transport", "entity_id": "user_4", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:34:48.199609+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 9.66}}}
# {"id": "d44d236d-487f-478e-a0a7-15631132729d", "sector": "transport", "entity_id": "user_5", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:34:48.199712+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 23.66}}}
# {"id": "65422bf3-9e1b-421c-a1d8-c1e8d300babd", "sector": "transport", "entity_id": "user_1", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:34:49.199974+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 27.92}}}
# {"id": "c0cbd513-2190-40f0-9437-f26acb68a757", "sector": "transport", "entity_id": "user_2", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:34:49.200485+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 13.42}}}
# {"id": "245e8a81-1abe-4039-8b93-0131f38d28d7", "sector": "transport", "entity_id": "user_3", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:34:49.200623+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 13.73}}}
# {"id": "baf7c614-116b-4a0f-bd4e-caabb330e4e0", "sector": "transport", "entity_id": "user_4", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:34:49.200749+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 28.21}}}
# {"id": "b1883552-5a91-44e9-b2b0-fb1891d8b243", "sector": "transport", "entity_id": "user_5", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:34:49.200906+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 17.45}}}
# {"id": "7a509aa0-8aef-45ba-9f96-49e2e4ede3cc", "sector": "industry", "entity_id": "factory_2", "activity_value": 14.576, "activity_unit": "kWh", "timestamp": "2026-01-12T09:34:50.191686+00:00", "metadata": {"source": "synthetic", "details": {"active_shift": true}}}
# {"id": "cac246c2-9b01-4c71-927b-bb6d38b0c842", "sector": "transport", "entity_id": "user_1", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:34:50.201143+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 22.99}}}
# {"id": "f32a5331-f11d-4586-b97b-3784e254cdb6", "sector": "transport", "entity_id": "user_2", "activity_value": 0.009, "activity_unit": "km", "timestamp": "2026-01-12T09:34:50.201426+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 33.47}}}
# {"id": "3951b1d0-8be1-4847-99df-469d27a068f4", "sector": "transport", "entity_id": "user_3", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:34:50.201637+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 13.04}}}
# {"id": "c906faf7-727e-4739-8517-8eb2ccf24290", "sector": "transport", "entity_id": "user_4", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:34:50.201878+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 27.79}}}
# {"id": "c0b25edb-1912-4e92-8483-6897f9d9bb68", "sector": "transport", "entity_id": "user_5", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:34:50.202096+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 29.74}}}
# {"id": "0041fc43-1203-4e76-8ad0-ae14b8620119", "sector": "transport", "entity_id": "user_1", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:34:51.202407+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 25.16}}}
# {"id": "e68f71b3-ded0-444d-93dd-a4cf3fdc5878", "sector": "transport", "entity_id": "user_2", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:34:51.202861+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 13.15}}}
# {"id": "53e5d125-013a-41b7-9fbc-d9b910f50dc6", "sector": "transport", "entity_id": "user_3", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:34:51.202995+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 22.04}}}
# {"id": "32505fd5-d452-479e-b8de-30099cf43f6e", "sector": "transport", "entity_id": "user_4", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:34:51.203102+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 13.56}}}
# {"id": "89c7cd0d-4150-472a-bd80-976d073f765c", "sector": "transport", "entity_id": "user_5", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:34:51.203204+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 23.31}}}
# {"id": "78e709aa-ca61-4013-a50c-19adfb883155", "sector": "transport", "entity_id": "user_1", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:34:52.203456+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 13.49}}}
# {"id": "cf47e176-0e99-422d-9bc9-6b00ed0e648d", "sector": "transport", "entity_id": "user_2", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:34:52.203930+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 20.82}}}
# {"id": "477ad185-9b7d-4ea8-bef9-1207c27af5e0", "sector": "transport", "entity_id": "user_3", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:34:52.204044+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 28.48}}}
# {"id": "3dca5c41-3750-44a1-a841-10b626f3b569", "sector": "transport", "entity_id": "user_4", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:34:52.204147+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 19.91}}}
# {"id": "527ad85f-a668-4983-aae6-2f5c2d3f8477", "sector": "transport", "entity_id": "user_5", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:34:52.204256+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 26.52}}}
# {"id": "02795237-ed32-4b5a-9873-4475b0af987e", "sector": "transport", "entity_id": "user_1", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:34:53.204517+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 24.06}}}
# {"id": "216afe43-4b8c-43d9-8bbf-5ab305f85342", "sector": "transport", "entity_id": "user_2", "activity_value": 0.002, "activity_unit": "km", "timestamp": "2026-01-12T09:34:53.205074+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 6.85}}}
# {"id": "ae754bb2-12ae-4ce5-bb66-fa816ec6d242", "sector": "transport", "entity_id": "user_3", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:34:53.205223+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 12.59}}}
# {"id": "ad0ad326-1a03-4b82-8f19-d48ca630f574", "sector": "transport", "entity_id": "user_4", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:34:53.205354+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 23.41}}}
# {"id": "fdff497e-c2aa-44b0-8ef8-bf137efea998", "sector": "transport", "entity_id": "user_5", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:34:53.205476+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 12.4}}}
# {"id": "16992045-f605-4532-bcf6-ebd1ecc0a2ba", "sector": "transport", "entity_id": "user_1", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:34:54.205733+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 21.57}}}
# {"id": "97d0082a-1e61-42af-9ae2-d53182f6a2a0", "sector": "transport", "entity_id": "user_2", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:34:54.206294+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 10.34}}}
# {"id": "3700c99e-3bb2-4e89-a17f-31a892a11f5e", "sector": "transport", "entity_id": "user_3", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:34:54.206422+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 17.68}}}
# {"id": "cc31370a-9693-4827-b7b5-d279a80bc6cc", "sector": "transport", "entity_id": "user_4", "activity_value": 0.012, "activity_unit": "km", "timestamp": "2026-01-12T09:34:54.206555+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 41.72}}}
# {"id": "9ab229c0-d412-4885-8863-1d78c978c158", "sector": "transport", "entity_id": "user_5", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:34:54.206664+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 18.94}}}
# {"id": "5c24cdae-f852-4c23-a733-539688e25ad3", "sector": "transport", "entity_id": "user_1", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:34:55.220492+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 18.29}}}
# {"id": "3e0ab92a-dfee-4c4b-b08d-47f9dfaeb807", "sector": "transport", "entity_id": "user_2", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:34:55.221020+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 21.74}}}
# {"id": "6629be29-afbe-4216-8795-5b4a6839a6aa", "sector": "transport", "entity_id": "user_3", "activity_value": 0.009, "activity_unit": "km", "timestamp": "2026-01-12T09:34:55.221138+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 33.71}}}
# {"id": "488dba5a-40da-487a-9c73-d228cf66c7d9", "sector": "transport", "entity_id": "user_4", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:34:55.221244+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 11.57}}}
# {"id": "40897b2d-f736-4b86-a30c-84e3db2b0c08", "sector": "transport", "entity_id": "user_5", "activity_value": 0.009, "activity_unit": "km", "timestamp": "2026-01-12T09:34:55.221344+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 32.35}}}
# {"id": "918848f9-0d8c-4657-a380-93937ea86f87", "sector": "transport", "entity_id": "user_1", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:34:56.221602+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 22.19}}}
# {"id": "cf79cda9-1f41-4057-bbcc-ffade7553df4", "sector": "transport", "entity_id": "user_2", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:34:56.222122+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 21.08}}}
# {"id": "0b47dbd2-9adf-4a47-a366-67c347dc89be", "sector": "transport", "entity_id": "user_3", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:34:56.222270+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 15.76}}}
# {"id": "b25b88a5-ef68-4af0-b7d6-272f0b380b01", "sector": "transport", "entity_id": "user_4", "activity_value": 0.002, "activity_unit": "km", "timestamp": "2026-01-12T09:34:56.222412+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 8.92}}}
# {"id": "4d725b5e-7803-42d4-8ef7-d324846f94e6", "sector": "transport", "entity_id": "user_5", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:34:56.222527+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 20.04}}}
# {"id": "4eb22541-7c35-497d-8b31-f239b95bc3b4", "sector": "transport", "entity_id": "user_1", "activity_value": 0.014, "activity_unit": "km", "timestamp": "2026-01-12T09:34:57.222765+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 49.31}}}
# {"id": "49577081-7205-41a1-8bef-b300e45de7e1", "sector": "transport", "entity_id": "user_2", "activity_value": 0.009, "activity_unit": "km", "timestamp": "2026-01-12T09:34:57.223223+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 33.36}}}
# {"id": "8337e4ea-aa2b-4517-8355-99adbca6ca3e", "sector": "transport", "entity_id": "user_3", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:34:57.223332+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 29.76}}}
# {"id": "804598a6-0962-4e51-9396-a980051d6c25", "sector": "transport", "entity_id": "user_4", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:34:57.223431+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 17.39}}}
# {"id": "88ee111a-9b96-490f-b9aa-851f5d0fb6a3", "sector": "transport", "entity_id": "user_5", "activity_value": 0.009, "activity_unit": "km", "timestamp": "2026-01-12T09:34:57.223523+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 33.53}}}
# {"id": "9e12331a-4ef7-4ff9-8bf3-209abf14d84c", "sector": "transport", "entity_id": "user_1", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:34:58.223789+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 11.54}}}
# {"id": "a7c31ed6-e9d7-4bbc-9feb-ec62953a847c", "sector": "transport", "entity_id": "user_2", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:34:58.224255+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 10.21}}}
# {"id": "295ff2e9-2dda-421d-adc1-0e73fb7cd02c", "sector": "transport", "entity_id": "user_3", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:34:58.224361+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 22.29}}}
# {"id": "c1a73278-5347-40f5-bc11-44c70cb3cdec", "sector": "transport", "entity_id": "user_4", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:34:58.224458+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 18.45}}}
# {"id": "e5e3d5e0-c55e-4a4e-8024-6f1d8cabfe00", "sector": "transport", "entity_id": "user_5", "activity_value": 0.012, "activity_unit": "km", "timestamp": "2026-01-12T09:34:58.224539+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 44.23}}}
# {"id": "524e58e5-fa34-4e9d-8aab-672b8a543297", "sector": "transport", "entity_id": "user_1", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:34:59.224756+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 12.52}}}
# {"id": "7bc112c7-4ba1-48bf-975a-41441c404b78", "sector": "transport", "entity_id": "user_2", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:34:59.225246+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 27.46}}}
# {"id": "2d2153d2-a500-4ea8-a774-3bbb32017e20", "sector": "transport", "entity_id": "user_3", "activity_value": 0.012, "activity_unit": "km", "timestamp": "2026-01-12T09:34:59.225385+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 44.3}}}
# {"id": "9076e725-c075-4f33-b69e-0ef7a1795b73", "sector": "transport", "entity_id": "user_4", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:34:59.225507+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 19.47}}}
# {"id": "06f3fc59-785d-47a5-a4c4-8381920f5670", "sector": "transport", "entity_id": "user_5", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:34:59.225624+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 17.48}}}
# {"id": "f16fb4fc-c733-450e-8058-297abef39b91", "sector": "industry", "entity_id": "factory_2", "activity_value": 14.195, "activity_unit": "kWh", "timestamp": "2026-01-12T09:35:00.192248+00:00", "metadata": {"source": "synthetic", "details": {"active_shift": true}}}
# {"id": "306dfef5-3738-481b-b0ab-69b965b6bbd8", "sector": "transport", "entity_id": "user_1", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:35:00.225896+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 16.54}}}
# {"id": "944c2dd8-1589-4183-9851-637fb1a232f6", "sector": "transport", "entity_id": "user_2", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:35:00.226307+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 25.82}}}
# {"id": "8bd4be8b-c906-4556-beb1-9ad5899d800f", "sector": "transport", "entity_id": "user_3", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:35:00.226707+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 25.02}}}
# {"id": "b9430c70-7ef2-4aee-9a19-b2fd3dbcfd41", "sector": "transport", "entity_id": "user_4", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:35:00.227207+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 16.49}}}
# {"id": "7ea2dfef-5fe5-4f06-8e4f-ccb13ec543ee", "sector": "transport", "entity_id": "user_5", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:35:00.227433+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 13.3}}}
# {"id": "a59cc0b0-b4b1-40dc-ae06-f490e1ee7c7a", "sector": "transport", "entity_id": "user_1", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:35:01.227929+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 26.9}}}
# {"id": "e5d11acf-05bf-4f19-a7e0-5a92463b2f14", "sector": "transport", "entity_id": "user_2", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:35:01.228429+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 22.33}}}
# {"id": "62325f2c-4428-4627-8df1-eb8835c4bdfe", "sector": "transport", "entity_id": "user_3", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:35:01.228577+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 15.23}}}
# {"id": "44e80e43-dcd7-4ed8-a44d-6bb1ceab80f6", "sector": "transport", "entity_id": "user_4", "activity_value": 0.01, "activity_unit": "km", "timestamp": "2026-01-12T09:35:01.228713+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 36.1}}}
# {"id": "0c6ca3e3-70ef-4aa2-9328-d7e006f507de", "sector": "transport", "entity_id": "user_5", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:35:01.228850+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 24.5}}}
# {"id": "411eade3-009e-48a4-988d-cff55290c9ec", "sector": "transport", "entity_id": "user_1", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:35:02.229123+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 20.96}}}
# {"id": "2f800daa-bdc4-4f09-bca8-ca10d9c2d48b", "sector": "transport", "entity_id": "user_2", "activity_value": 0.009, "activity_unit": "km", "timestamp": "2026-01-12T09:35:02.229596+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 32.98}}}
# {"id": "1c47c750-67df-4f82-bbd0-a9ddedae1025", "sector": "transport", "entity_id": "user_3", "activity_value": 0.017, "activity_unit": "km", "timestamp": "2026-01-12T09:35:02.229702+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 60.63}}}
# {"id": "012d00ed-8830-4eef-8691-8a715e56e3e3", "sector": "transport", "entity_id": "user_4", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:35:02.229827+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 17.04}}}
# {"id": "1a1d1484-f2b8-44f1-b9af-f9a3dae9c6d4", "sector": "transport", "entity_id": "user_5", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:35:02.229922+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 22.19}}}
# {"id": "429037e3-8aeb-4aca-afb7-f669402786b8", "sector": "transport", "entity_id": "user_1", "activity_value": 0.009, "activity_unit": "km", "timestamp": "2026-01-12T09:35:03.230155+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 31.22}}}
# {"id": "95b3cc62-5e45-4e72-9fe3-5df28649561c", "sector": "transport", "entity_id": "user_2", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:35:03.230569+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 24.6}}}
# {"id": "b9c03c12-d3b4-46fc-b25b-72659cbc3bd9", "sector": "transport", "entity_id": "user_3", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:35:03.230669+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 19.62}}}
# {"id": "7e3594a8-038f-442d-8301-26866e080846", "sector": "transport", "entity_id": "user_4", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:35:03.230765+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 13.89}}}
# {"id": "ac5a0c11-9fac-426d-9b67-58b80458a373", "sector": "transport", "entity_id": "user_5", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:35:03.230895+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 21.3}}}
# {"id": "5bbf4384-c291-497e-935e-1c31397fe4eb", "sector": "transport", "entity_id": "user_1", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:35:04.231138+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 21.08}}}
# {"id": "762ee4e8-ece1-40d9-9afd-0741c2ea6db8", "sector": "transport", "entity_id": "user_2", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:35:04.231671+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 25.97}}}
# {"id": "55229e84-b1c2-4965-815d-8262c0ec92ba", "sector": "transport", "entity_id": "user_3", "activity_value": 0.01, "activity_unit": "km", "timestamp": "2026-01-12T09:35:04.231795+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 36.15}}}
# {"id": "05ca981d-46b6-4d68-9391-7508080de2e8", "sector": "transport", "entity_id": "user_4", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:35:04.231951+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 14.28}}}
# {"id": "aae78032-d551-4c3d-aae6-ceaca00e6e1e", "sector": "transport", "entity_id": "user_5", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:35:04.232073+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 10.38}}}
# {"id": "15b329e4-aea2-4a45-85e5-7e60273dfd96", "sector": "transport", "entity_id": "user_1", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:35:05.232360+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 19.56}}}
# {"id": "21e41481-ad05-46bf-9118-872c5b97659b", "sector": "transport", "entity_id": "user_2", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:35:05.232902+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 25.35}}}
# {"id": "53e4c84e-3835-4601-a178-51dfc5bd9626", "sector": "transport", "entity_id": "user_3", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:35:05.233045+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 24.24}}}
# {"id": "72922c06-d67d-44bc-a07b-af7321d8cea2", "sector": "transport", "entity_id": "user_4", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:35:05.233179+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 16.24}}}
# {"id": "9d08373a-15ed-4f31-a479-1b042dbfc242", "sector": "transport", "entity_id": "user_5", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:35:05.233277+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 19.75}}}
# {"id": "ea33a71e-d77a-47af-bb91-0bc320bda495", "sector": "transport", "entity_id": "user_1", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:35:06.233546+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 17.93}}}
# {"id": "1621e7c7-31b2-4033-940c-3d86c5d7f566", "sector": "transport", "entity_id": "user_2", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:35:06.234056+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 11.73}}}
# {"id": "1367beb9-a3c4-4f30-b046-548f1e6a19cb", "sector": "transport", "entity_id": "user_3", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:35:06.234179+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 15.6}}}
# {"id": "7bf532aa-62d0-4a05-add0-3c7faec4d1a3", "sector": "transport", "entity_id": "user_4", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:35:06.234277+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 14.35}}}
# {"id": "bd8a301f-18cc-45f0-b2f7-ea4f140309cb", "sector": "transport", "entity_id": "user_5", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:35:06.234365+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 18.54}}}
# {"id": "49cfdb9f-c29a-454e-946f-0bee833d591f", "sector": "transport", "entity_id": "user_1", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:35:07.234597+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 19.5}}}
# {"id": "44bc39f1-2294-4d5c-914f-db6539728c13", "sector": "transport", "entity_id": "user_2", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:35:07.235123+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 24.41}}}
# {"id": "c3c5fe0e-665e-4024-a605-942e21f02cff", "sector": "transport", "entity_id": "user_3", "activity_value": 0.009, "activity_unit": "km", "timestamp": "2026-01-12T09:35:07.235246+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 31.21}}}
# {"id": "ed2493ce-0631-4c11-96c5-7d072d4b306a", "sector": "transport", "entity_id": "user_4", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:35:07.235359+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 22.16}}}
# {"id": "68bad5af-3872-4d4b-a600-f34680aca9c4", "sector": "transport", "entity_id": "user_5", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:35:07.235466+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 24.06}}}
# {"id": "333ef0fb-1e33-4f0c-9e36-d0e75248fb66", "sector": "transport", "entity_id": "user_1", "activity_value": 0.002, "activity_unit": "km", "timestamp": "2026-01-12T09:35:08.235728+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 8.96}}}
# {"id": "e2b9b86f-6bc0-4020-bdf6-92e0da353666", "sector": "transport", "entity_id": "user_2", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:35:08.236226+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 22.37}}}
# {"id": "a35e4e9b-a491-44e5-8e27-27b009e34a0b", "sector": "transport", "entity_id": "user_3", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:35:08.236377+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 22.01}}}
# {"id": "24475bb9-9fc3-4aab-970d-68f881d7fc7e", "sector": "transport", "entity_id": "user_4", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:35:08.236496+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 16.59}}}
# {"id": "4eb4f4ad-62b4-4751-8903-cdc2b287e1a7", "sector": "transport", "entity_id": "user_5", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:35:08.236607+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 25.89}}}
# {"id": "46e1293f-215c-448d-bbbe-12b269f869e2", "sector": "transport", "entity_id": "user_1", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:35:09.236883+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 21.12}}}
# {"id": "74ce628f-941e-4ea9-9a06-83fca4418b66", "sector": "transport", "entity_id": "user_2", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:35:09.237302+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 24.66}}}
# {"id": "d71289f7-6d81-4f7a-875b-b1b04399b2bf", "sector": "transport", "entity_id": "user_3", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:35:09.237408+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 27.4}}}
# {"id": "82d84753-56dc-47a0-9a9e-24ccefc80517", "sector": "transport", "entity_id": "user_4", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:35:09.237506+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 24.85}}}
# {"id": "695acd73-8918-4ba4-8087-088f16eba46f", "sector": "transport", "entity_id": "user_5", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:35:09.237598+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 13.61}}}
# {"id": "f600fad1-17bb-4f2e-91a0-c0ae196d7542", "sector": "industry", "entity_id": "factory_2", "activity_value": 11.779, "activity_unit": "kWh", "timestamp": "2026-01-12T09:35:10.192823+00:00", "metadata": {"source": "synthetic", "details": {"active_shift": true}}}
# {"id": "3e31ef25-4fa3-4419-83fe-40c83e64636b", "sector": "transport", "entity_id": "user_1", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:35:10.237798+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 27.38}}}
# {"id": "23fcffaf-4514-441d-a755-73dee5c865e4", "sector": "transport", "entity_id": "user_2", "activity_value": 0.01, "activity_unit": "km", "timestamp": "2026-01-12T09:35:10.237980+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 35.73}}}
# {"id": "796b5492-055b-4087-bc77-ab7c7347e807", "sector": "transport", "entity_id": "user_3", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:35:10.238103+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 29.02}}}
# {"id": "8fef5322-f611-484e-bd36-994d8b1467bc", "sector": "transport", "entity_id": "user_4", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:35:10.238233+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 14.28}}}
# {"id": "d7919d6e-8da2-4a01-a28c-7aa225e0c7b6", "sector": "transport", "entity_id": "user_5", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:35:10.238358+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 24.2}}}
# {"id": "9c832fa8-001e-46fa-9d93-0b7c47d63330", "sector": "transport", "entity_id": "user_1", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:35:11.238658+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 24.31}}}
# {"id": "855575f0-fe88-443f-b183-76e09f475646", "sector": "transport", "entity_id": "user_2", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:35:11.239173+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 25.73}}}
# {"id": "b5c79e52-7f89-4d85-b01c-73741b8d5996", "sector": "transport", "entity_id": "user_3", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:35:11.239305+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 27.22}}}
# {"id": "3ea4b2be-a788-408d-9fda-329bd5a10030", "sector": "transport", "entity_id": "user_4", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:35:11.239436+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 16.15}}}
# {"id": "37925c35-3145-4b28-8ad0-3b037779d593", "sector": "transport", "entity_id": "user_5", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:35:11.239544+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 15.41}}}
# {"id": "b9a02e0d-f5cc-45d3-95b4-e54425df39cb", "sector": "transport", "entity_id": "user_1", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:35:12.239888+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 13.61}}}
# {"id": "78f8e784-7117-4d27-aef6-3a0e3a7489eb", "sector": "transport", "entity_id": "user_2", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:35:12.240354+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 30.09}}}
# {"id": "86da9854-de56-4e45-ab26-74e28b5bfcb6", "sector": "transport", "entity_id": "user_3", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:35:12.240477+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 11.31}}}
# {"id": "9664e540-004b-4557-adf6-e31e4b771564", "sector": "transport", "entity_id": "user_4", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:35:12.240575+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 18.34}}}
# {"id": "924c39b4-915f-4123-b46e-207605792e8a", "sector": "transport", "entity_id": "user_5", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:35:12.240663+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 25.93}}}
# {"id": "2e8c7923-1abb-43f9-ad92-32725f6ef57c", "sector": "transport", "entity_id": "user_1", "activity_value": 0.011, "activity_unit": "km", "timestamp": "2026-01-12T09:35:13.240954+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 38.36}}}
# {"id": "c9723241-ad18-4f12-b802-2f33fb0d3ac6", "sector": "transport", "entity_id": "user_2", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:35:13.241408+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 21.32}}}
# {"id": "274cad94-885a-438c-8683-9cb07027ff9c", "sector": "transport", "entity_id": "user_3", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:35:13.241515+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 19.69}}}
# {"id": "e103c9b7-3e73-4284-9825-26af2d9d6ad2", "sector": "transport", "entity_id": "user_4", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:35:13.241608+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 28.79}}}
# {"id": "413ba01c-1728-4c48-b6ca-5add290bfbc5", "sector": "transport", "entity_id": "user_5", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:35:13.241705+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 23.59}}}
# {"id": "eaef2445-6f40-438c-99c3-aa8c85c0f10c", "sector": "transport", "entity_id": "user_1", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:35:14.241976+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 28.55}}}
# {"id": "5c6a47d0-c048-406e-a11d-23506ea1e84b", "sector": "transport", "entity_id": "user_2", "activity_value": 0.01, "activity_unit": "km", "timestamp": "2026-01-12T09:35:14.242500+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 34.43}}}
# {"id": "c30d29e6-c428-4634-ae10-1c292171b443", "sector": "transport", "entity_id": "user_3", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:35:14.242641+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 12.79}}}
# {"id": "cf8972b8-9da8-46cd-ac70-95a753731352", "sector": "transport", "entity_id": "user_4", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:35:14.242756+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 19.25}}}
# {"id": "1e3988cb-081c-499e-b5d3-f3a272bf773d", "sector": "transport", "entity_id": "user_5", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:35:14.242905+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 16.05}}}
# {"id": "e8a7e0be-98a8-48c1-93f6-1da895631e6a", "sector": "transport", "entity_id": "user_1", "activity_value": 0.009, "activity_unit": "km", "timestamp": "2026-01-12T09:35:15.243262+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 31.09}}}
# {"id": "1f894319-05fb-4a32-b504-298acd9c7ac2", "sector": "transport", "entity_id": "user_2", "activity_value": 0.009, "activity_unit": "km", "timestamp": "2026-01-12T09:35:15.243729+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 34.04}}}
# ...
# {"id": "bc66bfa8-6017-4bc2-ae70-77be601c4fbb", "sector": "transport", "entity_id": "user_4", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:37:32.387202+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 20.99}}}
# {"id": "95fdb193-17b9-4e13-b8ee-6de0c5e2daae", "sector": "transport", "entity_id": "user_5", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:37:32.387275+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 9.69}}}
# {"id": "e02e3b43-87b3-4f1e-a3db-a1a134c6dd02", "sector": "transport", "entity_id": "user_1", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:37:33.387514+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 12.99}}}
# {"id": "c656e11b-5930-4e02-b495-27de4ac1775b", "sector": "transport", "entity_id": "user_2", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:37:33.387988+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 17.92}}}
# {"id": "372b7ea5-c4c9-4b2f-8304-c4dd076e3516", "sector": "transport", "entity_id": "user_3", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:37:33.388251+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 21.15}}}
# {"id": "5aaa1274-34ce-4d46-b5bf-0cc4ffc31aae", "sector": "transport", "entity_id": "user_4", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:37:33.388349+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 25.37}}}
# {"id": "ec0f19e8-3f17-4db6-b10b-d9ae95d68a2c", "sector": "transport", "entity_id": "user_5", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:37:33.388519+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 22.48}}}
# {"id": "0fdd0bab-d4f9-4170-8be9-07826c8d092a", "sector": "transport", "entity_id": "user_1", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:37:34.388751+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 15.24}}}
# {"id": "70fbd115-b58d-40c0-99fc-338b37d3fcb3", "sector": "transport", "entity_id": "user_2", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:37:34.389224+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 14.54}}}
# {"id": "68c951bd-f38a-4dda-a195-6af5fc7be169", "sector": "transport", "entity_id": "user_3", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:37:34.389347+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 17.95}}}
# {"id": "c99bcc74-4ed1-4340-a6bd-cce7df124dc4", "sector": "transport", "entity_id": "user_4", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:37:34.389455+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 25.56}}}
# {"id": "f2e2a423-43b8-4f27-91d8-91838c9f3ceb", "sector": "transport", "entity_id": "user_5", "activity_value": 0.01, "activity_unit": "km", "timestamp": "2026-01-12T09:37:34.389543+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 34.95}}}
# {"id": "b3f4b736-4e13-499c-b224-64f14602898e", "sector": "transport", "entity_id": "user_1", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:37:35.389847+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 9.56}}}
# {"id": "f828f688-c684-4b91-a062-80362b348c8d", "sector": "transport", "entity_id": "user_2", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:37:35.390287+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 21.43}}}
# {"id": "56f0ff62-740b-44b3-bf01-2ce96a54d96f", "sector": "transport", "entity_id": "user_3", "activity_value": 0.002, "activity_unit": "km", "timestamp": "2026-01-12T09:37:35.390413+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 8.07}}}
# {"id": "da014add-ecd7-49d9-9fd2-1846c554c157", "sector": "transport", "entity_id": "user_4", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:37:35.390528+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 14.92}}}
# {"id": "a63bd241-b400-4649-9032-16fffd82bccf", "sector": "transport", "entity_id": "user_5", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:37:35.390605+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 27.48}}}
# {"id": "1f2a5237-af9e-4ee6-b89c-8f413d0fa98c", "sector": "transport", "entity_id": "user_1", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:37:36.390876+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 24.8}}}
# {"id": "d7469821-dd8b-4155-b46f-28f3c6521bdc", "sector": "transport", "entity_id": "user_2", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:37:36.391314+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 13.39}}}
# {"id": "b5a2902c-3a9b-46c2-8e61-909adc0b054d", "sector": "transport", "entity_id": "user_3", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:37:36.391438+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 14.94}}}
# {"id": "ce165fcd-bc52-48b8-8102-2848b457d2eb", "sector": "transport", "entity_id": "user_4", "activity_value": 0.009, "activity_unit": "km", "timestamp": "2026-01-12T09:37:36.391525+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 32.3}}}
# {"id": "de29e520-ad21-4153-9592-88859e752ec8", "sector": "transport", "entity_id": "user_5", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:37:36.391598+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 23.87}}}
# {"id": "bb0f9e48-6313-4fca-b62b-bb4235a85c8c", "sector": "transport", "entity_id": "user_1", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:37:37.391841+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 24.56}}}
# {"id": "6492754a-9a82-4c97-beab-78d273e25a5e", "sector": "transport", "entity_id": "user_2", "activity_value": 0.011, "activity_unit": "km", "timestamp": "2026-01-12T09:37:37.392289+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 38.79}}}
# {"id": "00e269e9-a28b-45db-8fe6-c7e9440a9b8a", "sector": "transport", "entity_id": "user_3", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:37:37.392392+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 26.53}}}
# {"id": "94e7f703-dd98-4de2-b08b-5c6fb0f6f5bb", "sector": "transport", "entity_id": "user_4", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:37:37.392482+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 24.08}}}
# {"id": "0d7655bb-5720-460d-a1a7-10cb076b5bec", "sector": "transport", "entity_id": "user_5", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:37:37.392558+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 11.87}}}
# {"id": "838dba31-43a3-41c1-8469-c65d469b474a", "sector": "transport", "entity_id": "user_1", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:37:38.392796+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 25.25}}}
# {"id": "282b83c7-b6d7-4498-8411-218547906fa5", "sector": "transport", "entity_id": "user_2", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:37:38.393249+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 26.13}}}
# {"id": "946e61ae-25b4-47b2-b9be-11ccdb6d008c", "sector": "transport", "entity_id": "user_3", "activity_value": 0.011, "activity_unit": "km", "timestamp": "2026-01-12T09:37:38.393350+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 38.64}}}
# {"id": "77bbe350-0b22-49ab-b232-596e8e1820e4", "sector": "transport", "entity_id": "user_4", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:37:38.393435+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 26.24}}}
# {"id": "a6c54e83-15be-4ed2-bb56-d380d48c25a1", "sector": "transport", "entity_id": "user_5", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:37:38.393518+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 28.67}}}
# {"id": "044803f8-34f6-4a34-b959-8ff7df0b37f6", "sector": "transport", "entity_id": "user_1", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:37:39.393781+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 14.86}}}
# {"id": "4d749fe0-9ba1-4178-b71d-d14fc93c7974", "sector": "transport", "entity_id": "user_2", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:37:39.394265+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 16.88}}}
# {"id": "c804efba-ee9a-4ccd-9b8e-bf721bb69227", "sector": "transport", "entity_id": "user_3", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:37:39.394366+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 27.3}}}
# {"id": "08fc1beb-b21b-45ea-98c9-9d3d4b6a5319", "sector": "transport", "entity_id": "user_4", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:37:39.394454+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 18.83}}}
# {"id": "05e9bda4-4e3d-4264-a8fc-b78f159421b0", "sector": "transport", "entity_id": "user_5", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:37:39.394539+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 30.3}}}
# {"id": "09de1e84-86c5-412c-aa8c-b57a87631404", "sector": "electricity", "entity_id": "house_1", "activity_value": 0.002, "activity_unit": "kWh", "timestamp": "2026-01-12T09:37:40.193827+00:00", "metadata": {"source": "synthetic", "details": {"hour": 9, "peak": false}}}
# {"id": "8dd5dce6-70db-4440-a28e-95fe1b9fe216", "sector": "electricity", "entity_id": "house_2", "activity_value": 0.002, "activity_unit": "kWh", "timestamp": "2026-01-12T09:37:40.194277+00:00", "metadata": {"source": "synthetic", "details": {"hour": 9, "peak": false}}}
# {"id": "a3f0e3cd-ad9c-4fb6-9fa4-f2b715a25780", "sector": "electricity", "entity_id": "house_3", "activity_value": 0.001, "activity_unit": "kWh", "timestamp": "2026-01-12T09:37:40.194398+00:00", "metadata": {"source": "synthetic", "details": {"hour": 9, "peak": false}}}
# {"id": "e26f0ac6-65f5-49cc-8deb-3bb8600471e6", "sector": "industry", "entity_id": "factory_2", "activity_value": 10.59, "activity_unit": "kWh", "timestamp": "2026-01-12T09:37:40.200995+00:00", "metadata": {"source": "synthetic", "details": {"active_shift": true}}}
# {"id": "3ea7e6c8-9f4d-49d3-8f6e-e587633fadbf", "sector": "transport", "entity_id": "user_1", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:37:40.394776+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 13.23}}}
# {"id": "fffaf865-0bae-44c4-b896-7a4eb7cad71a", "sector": "transport", "entity_id": "user_2", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:37:40.394968+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 12.7}}}
# {"id": "5b7d23fa-d129-4e60-b29c-d458cd17c377", "sector": "transport", "entity_id": "user_3", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:37:40.395050+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 11.26}}}
# {"id": "d8d8db86-25e4-4ef3-95ff-67c0911eb0e0", "sector": "transport", "entity_id": "user_4", "activity_value": 0.009, "activity_unit": "km", "timestamp": "2026-01-12T09:37:40.395275+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 34.08}}}
# {"id": "2185e619-98a4-49bf-91d5-e8f191ebe54e", "sector": "transport", "entity_id": "user_5", "activity_value": 0.009, "activity_unit": "km", "timestamp": "2026-01-12T09:37:40.395401+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 33.9}}}
# {"id": "6ad7eaf3-a07a-414c-8abc-e530a9d54e8c", "sector": "transport", "entity_id": "user_1", "activity_value": 0.01, "activity_unit": "km", "timestamp": "2026-01-12T09:37:41.395694+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 36.51}}}
# {"id": "5ce8e297-167c-4861-bf4d-3560cbfd01c8", "sector": "transport", "entity_id": "user_2", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:37:41.396177+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 24.37}}}
# {"id": "248f781c-31a2-4ef6-a285-066e75e4ca9f", "sector": "transport", "entity_id": "user_3", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:37:41.396299+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 17.56}}}
# {"id": "b4071c57-83b3-4f6f-9513-689a00a4c82b", "sector": "transport", "entity_id": "user_4", "activity_value": 0.005, "activity_unit": "km", "timestamp": "2026-01-12T09:37:41.396397+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 16.79}}}
# {"id": "422ed2ba-ac0d-46f1-91eb-9aac863524f3", "sector": "transport", "entity_id": "user_5", "activity_value": 0.006, "activity_unit": "km", "timestamp": "2026-01-12T09:37:41.396510+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 22.58}}}
# {"id": "c4c3259d-b714-4d36-a4fa-bcc79ccdeea2", "sector": "transport", "entity_id": "user_1", "activity_value": 0.01, "activity_unit": "km", "timestamp": "2026-01-12T09:37:42.396740+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 37.27}}}
# {"id": "604efd00-9d8d-4102-851d-3ecb20cb3692", "sector": "transport", "entity_id": "user_2", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:37:42.397182+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 14.3}}}
# {"id": "e132be05-ce2e-4170-a3f5-f4de4cb07f6f", "sector": "transport", "entity_id": "user_3", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:37:42.397282+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 24.15}}}
# {"id": "7ee56117-a559-4833-bdd1-cb4d585ef7ac", "sector": "transport", "entity_id": "user_4", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:37:42.397371+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 11.78}}}
# {"id": "2b9b7f8e-cb1e-4c66-ba23-de27013cc949", "sector": "transport", "entity_id": "user_5", "activity_value": 0.008, "activity_unit": "km", "timestamp": "2026-01-12T09:37:42.397449+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 29.17}}}
# {"id": "22e77b17-1b7c-49b6-976e-524d1cd19d73", "sector": "transport", "entity_id": "user_1", "activity_value": 0.01, "activity_unit": "km", "timestamp": "2026-01-12T09:37:43.397699+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 37.65}}}
# {"id": "042c6735-1c69-451d-8c6a-af0bec1c25d6", "sector": "transport", "entity_id": "user_2", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:37:43.398153+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 12.16}}}
# {"id": "defddd5b-2cb0-4eef-801b-daa612de86c7", "sector": "transport", "entity_id": "user_3", "activity_value": 0.003, "activity_unit": "km", "timestamp": "2026-01-12T09:37:43.398269+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 10.3}}}
# {"id": "6cb59952-f4e3-4aaf-9598-c62fbc32e935", "sector": "transport", "entity_id": "user_4", "activity_value": 0.007, "activity_unit": "km", "timestamp": "2026-01-12T09:37:43.398375+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 25.4}}}
# {"id": "8019bb28-8120-44ed-ac3e-3b56f2455120", "sector": "transport", "entity_id": "user_5", "activity_value": 0.004, "activity_unit": "km", "timestamp": "2026-01-12T09:37:43.398461+00:00", "metadata": {"source": "synthetic", "details": {"speed_kmh": 14.45}}}
